# %% [markdown]
# ## Natural Language Processing
#
# NLP is a field in computer science and AI that gives machines an ability to understand human language better and to assist in language related tasks

# %% [markdown]
# #### NLP USE CASES
#
# - GMAIL Auto complete
# - Keyboard suggestions
# - Spam Filter on Gmail
# - Language Translation - High accuracy
# - Costumer Service Chatbots
# - Voice Assistant like alexa , google assistant, google now, google bard, siri
# - Automated news generation by news

# %% [markdown]
# - - we will be using python , spaCy, Gensim ,NLTK , skleran, tensorflow , hugging face and pytorch for this complete NLP Class
