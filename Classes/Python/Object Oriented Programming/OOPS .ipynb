# %% [markdown]
# ## oops
#
#
# - Procedural --> line by line
# - Functional --> based on functions
# - OOPS --> Have to work with expendable code and maintainable code as you have different classes so your code become moduler .
#
#
#
# - if you  have multiple salers how can you store there data in the project
# we can make multiple data types with the help of classes
#
#
#
# OOPS is a programming paradigm which help you to scale your product .
# in ml you have to build end to end project so you need oops for that
#
#
#
# ![OOPS example](./images/1.png)
#
#
#
# - oops help you to build blueprint of the product so you can build on top of that you can get the properties of that blueprint
#
# - it is inspired from reallife
#
# oops help to
# 1. define our own data type
# 2. Fenerality to specificity
#
#
#
# oops is inspiered from real life
#
#
#
# The most complex machine is human
#
#
# In oops we have to study
#
# - Class
# - Object
# - Encapsulation
# - Inheritance
# - Polymorphism
# - Abstraction
#
#
#
#
# ## class
#
# - A class is a self defined datatype
# - We can say it is the blueprint of object

# %%
a=5
type(a)
# Out:
# int

# %%
b = 3.3
type(b)
# Out:
# float

# %%
s1 = "Hello, World!"
type(s1)
# Out:
# str

# %%
# 
# int, float, str are classes in python.

# %%
# Blueprint of a car is called as class.
# Toyota, Honda, Ford are objects of class car.

# %%
# cars class has some properties and behaviors.
# like color, model, year (properties) which are attributes
# and start(), stop() (behaviors) which are methods/functions.

# %%
# -----------------------NANO DIDI------------------------

# %%
l1 = [1, 2, 3, 4, 5]
type(l1)
# Out:
# list

# %%
l1.append(6)
l1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#syntax to create a class
class Harivansh:
    #class body
    pass

#syntax to create an object
obj1 = Harivansh()
type(obj1)
# Out:
# __main__.Harivansh

# %%
class car:
    #attributes
    color = "red"

    #method
    def start(self):
        print("car started")
    def stop(self): 
        print("car stopped")
        
#creating object of class car
suzuki = car()
print(suzuki.color)
suzuki.start()
# Out:
# red
# car started

# %%
suzuki.stop()
# Out:
# car stopped

# %%
# object is an instance of our class.

# %%
# Object 


c1 = 3+4j
c2 = 7 + 2.5j

print(type(c1+c2))
# Out:
# <class 'complex'>

# %%
## everything in python is an object.

# %%
type(int)
# Out:
# type

# %%
type(type)
# Out:
# type

# %%
type(suzuki)
# Out:
# __main__.car

# %%
a = int()
type(a)
# Out:
# int

# %%
l1 = []

print(type(l1))
l2 = ()
print(type(l2))
type(l2)
d1 = {}
type(d1)
print(type(d1))

s1 = set()
print(type(s1))
type(s1)
f1 = frozenset()
type(f1)
print(type(f1))
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>
# <class 'set'>
# <class 'frozenset'>

# %%
# what is object literal?
# an object literal is a notation for representing an object in code.
# For example, in Python, a dictionary can be created using curly braces {} as an object literal:
my_dict = {'key1': 'value1', 'key2': 'value2'}
type(my_dict)
print(my_dict)
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %%
## student class

class Student:
    name = "John Doe"
    age = 20

    def study(self):
        print(f"{self.name} is studying.")

    def attend_class(self):
        print(f"{self.name} is attending class.")

# %%
harivansh = Student()
harivansh.name = "Harivansh Rai Bachchan"
harivansh.age = 30
harivansh.study()
harivansh.attend_class()
# Out:
# Harivansh Rai Bachchan is studying.
# Harivansh Rai Bachchan is attending class.

# %%
c1 = complex(3, 4)
type(c1)
print(type(c1))
# or we can use complex literal
c2 = 5 + 6j
type(c2)
print(type(c2))
# Out:
# <class 'complex'>
# <class 'complex'>

# %%
#we do create construct an onject of a class is an inbuilt methpd __init__ wqhich is called known as constructor

# %%
# using constructor for class student


class Student:    
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def study(self):
        print(f"{self.name} is studying.")
    def attend_class(self):
        print(f"{self.name} is attending class.")

# %%
harshit = Student()
harshit.name = "Harshit"
harshit.age = 22

harshit.study()
harshit.attend_class()
harshit.age
# Out:
# Harshit is studying.
# Harshit is attending class.
# 22

# %%
# self parameter is a reference to the current instance of the class.
class puiya:
    def __init__():
        print("This is constructor")


p = puiya()
# this will give error because self parameter is missing
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 7
#       3     def __init__():
#       4         print("This is constructor")
# ----> 7 p = puiya()
#
# TypeError: puiya.__init__() takes 0 positional arguments but 1 was given

# %%
# the self parameter must be the first parameter of any method in the class, including the __init__ method.
class puiya:
    def __init__(self):
        print("This is constructor")
        
        
p = puiya()
# Out:
# This is constructor

# %%
# whenever we create an object of a class the __init__ method is automatically called.


# this init method is used to initialize the attributes of the class.

# constructor is the method which is called automatically when an object of the class is created.
# special method __init__ is known as constructor.

# %%
# advantage and use of constructor
# 1. Automatic Initialization: The constructor is automatically called when an object is created, ensuring that the object is properly initialized without requiring explicit calls to initialization methods.

# 2. Code Clarity: Using a constructor makes the code cleaner and easier to understand, as the initialization logic is encapsulated within the class itself.
# 3. Consistency: Constructors help maintain consistency in object creation by enforcing that certain attributes are set when an object is instantiated.
# 4. Reduced Boilerplate Code: By using constructors, you can reduce the amount of repetitive code needed to initialize objects, leading to more concise and maintainable code.
# 5. Encapsulation of Initialization Logic: Constructors allow you to encapsulate complex initialization logic within the class, making it easier to manage and modify in the future.

# %%
# usecase
# backgrouund check in companies when employee joins
# internet check for apps 
# configuration reloted check before running an application
# --- IGNORE --

# %%
# oop is a practical subject

# %%
# a class is a blueprint of an object which is used to define a seperate data type

# everything in python is an object

a = 2 
# a is an object of class int 

l = [1,"h",5]
print(type(l))
# Out:
# <class 'list'>

# %%
# in class class ka naam should be in pascal case 

# means the name of class should be in pascal case 
# and method name should be in snake case

# %%
# object literal is the easy way to create the object 
# for list we have list literal 
# for string we have string literal

# %%
# lets make a software for atm machine 
# account balance
# deposit
# check balance 
# atm pin 
# create pin 
# withdrawl



class Atm:
    #method are the function written inside a class
    def __init__(self):
        self.pin = ""
        self.balance = 0
        self.menu ()
        
    def menu(self):
        user_input = input("""Hello how would you like to proceed
                           1.Enter 1 to create pin :
                           2. Enter 2 to deposit
                           3. ENter 3 to withdraw
                           4. Enter 4 to check balance
                           5. Enter 5 to exit""")
        if user_input == '1':
            print("Enter your pin")
            self.create_pin()
        elif user_input == '2':
            print("deposit")
            self.deposit()
        elif user_input == '3':
            print("WIthdraaw")
            self.withdrawl()
        elif user_input == '4':
            print("check balance")
        elif user_input == '5':
            print("Exit")
            
    def create_pin(self):
        self.pin = input("ENter your pin")
        print("pin set successfully")
        
    def deposit(self):
        s = input("ENter your pin")
        if s == self.pin:
            amount = int(input("Enter amount to Deposit"))
            self.balance = self.balance + amount
            print(f"Deposit successful the remaining balance is {self.balance}")
        else:
            print("Wrong pin entered")

    def withdrawl(self):
        s = input("ENter your pin")
        if s == self.pin:
            amount = int(input("Enter amount to Withdraw"))
            if amount<self.balance:
                self.balance = self.balance - amount
                print(f"Withdrawl successful the remaining balance is {self.balance}")
            else:
                print("not sufficient balance")
        else:
            print("Wrong pin entered")
        
    def checkbal(self):
        s = input("ENter your pin")
        if s == self.pin:
            print(f"the balance is {self.balance}")
        else:
            print("Invalid Pin")

# %%
hdfc = Atm()
# Out:
# Enter your pin
# pin set successfully

# %%
sbi = Atm()
# Out:
# Enter your pin
# pin set successfully

# %%
sbi.checkbal()
# Out:
# the balance is 665544

# %%
hdfc.deposit()
# Out:
# Deposit successful the remaining balance is 2255

# %%
hdfc.checkbal()
# Out:
# the balance is 2255

# %%
sbi.deposit()
# Out:
# Deposit successful the remaining balance is 665544

# %%
sbi.withdrawl()
# Out:
# Withdrawl successful the remaining balance is 659978

# %%
# constructor is a magic / special and dunder method 
# you can not make dunder method 
# in python we do have pre defined dunder // special / magic method but you can not create them

# %%
l1.append(7)

# %%
l1
# Out:
# [7]

# %%
# create a python class named complex number to rep

''' 
Theory:
A complex number is a number that can be expressed in the form a + bi, where 'a' and 'b' are real numbers, and 'i' is the imaginary unit, which satisfies the equation i² = -1. In this expression, 'a' is called the real part, and 'b' is called the imaginary part of the complex number.
Operations on Complex Numbers:
1. Addition: (a + bi) + (c + di) = (a + c) + (b + d)i
2. Subtraction: (a + bi) - (c + di) = (a - c) + (b - d)i
3. Multiplication: (a + bi) * (c + di) = (ac - bd) + (ad + bc)i
4. Division: (a + bi) / (c + di) = [(ac + bd) / (c² + d²)] + [(bc - ad) / (c² + d²)]i, provided that c + di ≠ 0.
5. Comparison: Two complex numbers are equal if their real parts and imaginary parts are equal, i.e., (a + bi) = (c + di) if and only if a = c and b = d.

'''
# Theory:


class ComplexNumber:
    def __init__ (self,real, imag):
        self.real = real
        self.imag = imag

# %%
# magic methods also known as dunder methods or special methods in python are the methods which have double underscores before and after their name like __init__, __add__, __sub__ etc.
