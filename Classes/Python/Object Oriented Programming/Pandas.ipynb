# %%
##### updated pandas

# %%
import numpy as np 
import pandas as pd

# %%
### data frame is just tables and with extra funcitonlaity 


#we can create a data frame by ourself with like this 
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns =["A","B","C"] , index =["x" ,"y", "z"])
df.head()
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
print(df)
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
x = df.index
print(x)
# Out:
# Index(['x', 'y', 'z'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.nunique()
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df['A'].unique
# Out:
# <bound method Series.unique of x    1
# y    4
# z    7
# Name: A, dtype: int64>

# %%
df.shape
# Out:
# (3, 3)

# %%
df.size
# Out:
# 9

# %%
##################### Load data from files ############

# %%
# load a csv 
coffee = pd.read_csv("coffee.csv")

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
biox = pd.read_csv("https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/bios.csv")

biox.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
# csv are readable , undestandable , but size is huge

# %%
results = pd.read_parquet("results.parquet")
results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %%
olympics_data = pd.read_excel("olympics-data.xlsx" , sheet_name="results")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 olympics_data = pd.read_excel("olympics-data.xlsx" , sheet_name="results")
#
# File c:\Users\hariv\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#     507 try:
# --> 508     data = io.parse(
#     509         sheet_name=sheet_name,
#     510         header=header,
#     511         names=names,
# ...

# %%
olympics_data
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
biox.to_csv("Harivansh.csv")

# %%
# accessing data with python
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
display(coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.head(10)
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25
# 6   Thursday    Espresso          40
# 7   Thursday       Latte          30
# 8     Friday    Espresso          45
# 9     Friday       Latte          35

# %%
coffee.tail()
# Out:
#          Day Coffee Type  Units Sold
# 9     Friday       Latte          35
# 10  Saturday    Espresso          45
# 11  Saturday       Latte          35
# 12    Sunday    Espresso          45
# 13    Sunday       Latte          35

# %%
coffee.sample(6 , random_state=4)
# Out:
#           Day Coffee Type  Units Sold
# 4   Wednesday    Espresso          35
# 3     Tuesday       Latte          20
# 11   Saturday       Latte          35
# 9      Friday       Latte          35
# 6    Thursday    Espresso          40
# 13     Sunday       Latte          35

# %%
# loo and iloc
coffee.loc[0:4]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.loc[[0,2,4]]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 2    Tuesday    Espresso          30
# 4  Wednesday    Espresso          35

# %%
coffee.loc[1:,["Day","Units Sold"]]
# Out:
#           Day  Units Sold
# 1      Monday          15
# 2     Tuesday          30
# 3     Tuesday          20
# 4   Wednesday          35
# 5   Wednesday          25
# 6    Thursday          40
# 7    Thursday          30
# 8      Friday          45
# 9      Friday          35
# 10   Saturday          45
# 11   Saturday          35
# 12     Sunday          45
# 13     Sunday          35

# %%
######### iloc use only index

coffee.iloc[1:,[0,1]]
# Out:
#           Day Coffee Type
# 1      Monday       Latte
# 2     Tuesday    Espresso
# 3     Tuesday       Latte
# 4   Wednesday    Espresso
# 5   Wednesday       Latte
# 6    Thursday    Espresso
# 7    Thursday       Latte
# 8      Friday    Espresso
# 9      Friday       Latte
# 10   Saturday    Espresso
# 11   Saturday       Latte
# 12     Sunday    Espresso
# 13     Sunday       Latte

# %%
coffee.index = coffee["Day"]

# %%
coffee.iloc["Monday":"Wednesday"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 coffee.iloc["Monday":"Wednesday"]
#
# File c:\Users\hariv\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\hariv\anaconda3\Lib\site-packages\pandas\core\indexing.py:1729, in _iLocIndexer._getitem_axis(self, key, axis)
#    1723     raise IndexError(
#    1724         "DataFrame indexer is not allowed for .iloc\n"
#    1725         "Consider using .loc for automatic alignment."
#    1726     )
#    1728 if isinstance(key, slice):
# -> 1729     return self._get_slice_axis(key, axis=axis)
#    1731 if is_iterator(key):
# ...

# %%
coffee.iloc["Monday","Units Sold"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\hariv\anaconda3\Lib\site-packages\pandas\core\indexing.py:966, in _LocationIndexer._validate_tuple_indexer(self, key)
#     965 try:
# --> 966     self._validate_key(k, i)
#     967 except ValueError as err:
#
# File c:\Users\hariv\anaconda3\Lib\site-packages\pandas\core\indexing.py:1614, in _iLocIndexer._validate_key(self, key, axis)
#    1613 else:
# -> 1614     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 coffee.iloc["Monday","Units Sold"]
#
# ...

# %%
coffee.iloc[0:3,"Units Sold"] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 coffee.iloc[0:3,"Units Sold"] = 100
#
# File c:\Users\hariv\anaconda3\Lib\site-packages\pandas\core\indexing.py:911, in _LocationIndexer.__setitem__(self, key, value)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File c:\Users\hariv\anaconda3\Lib\site-packages\pandas\core\indexing.py:1942, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1939 # align and set the values
#    1940 if take_split_path:
#    1941     # We have to operate column-wise
# -> 1942     self._setitem_with_indexer_split_path(indexer, value, name)
#    1943 else:
#    1944     self._setitem_single_block(indexer, value, name)
#
# ...

# %%
coffee.head()
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso        25.0
# Monday        Monday       Latte        15.0
# Tuesday      Tuesday    Espresso        30.0
# Tuesday      Tuesday       Latte        20.0
# Wednesday  Wednesday    Espresso        35.0

# %%
coffee.iloc[1,2]
# Out:
# np.float64(15.0)

# %%
coffee.Day
# Out:
# Day
# Monday          Monday
# Monday          Monday
# Tuesday        Tuesday
# Tuesday        Tuesday
# Wednesday    Wednesday
# Wednesday    Wednesday
# Thursday      Thursday
# Thursday      Thursday
# Friday          Friday
# Friday          Friday
# Saturday      Saturday
# Saturday      Saturday
# Sunday          Sunday
# Sunday          Sunday
# NaN                NaN
# Name: Day, dtype: object

# %%
coffee["Units Sold"]
# Out:
# Day
# Monday        25.0
# Monday        15.0
# Tuesday       30.0
# Tuesday       20.0
# Wednesday     35.0
# Wednesday     25.0
# Thursday      40.0
# Thursday      30.0
# Friday        45.0
# Friday        35.0
# Saturday      45.0
# Saturday      35.0
# Sunday        45.0
# Sunday        35.0
# NaN          100.0
# Name: Units Sold, dtype: float64

# %%
coffee.sort_values(["Units Sold","Coffee Type"])
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday       Latte        15.0
# Tuesday      Tuesday       Latte        20.0
# Monday        Monday    Espresso        25.0
# Wednesday  Wednesday       Latte        25.0
# Tuesday      Tuesday    Espresso        30.0
# Thursday    Thursday       Latte        30.0
# Wednesday  Wednesday    Espresso        35.0
# Friday        Friday       Latte        35.0
# Saturday    Saturday       Latte        35.0
# Sunday        Sunday       Latte        35.0
# Thursday    Thursday    Espresso        40.0
# Friday        Friday    Espresso        45.0
# Saturday    Saturday    Espresso        45.0
# Sunday        Sunday    Espresso        45.0
# NaN              NaN         NaN       100.0

# %%
for index, row in coffee.iterrows():
    print(index)
    print(row,["Units Sold"])
    print("\n\n")
# Out:
# Monday
# Day              Monday
# Coffee Type    Espresso
# Units Sold         25.0
# Name: Monday, dtype: object ['Units Sold']
#
#
#
# Monday
# Day            Monday
# Coffee Type     Latte
# Units Sold       15.0
# Name: Monday, dtype: object ['Units Sold']
#
#
#
# Tuesday
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold         30.0
# Name: Tuesday, dtype: object ['Units Sold']
#
#
#
# Tuesday
# Day            Tuesday
# Coffee Type      Latte
# Units Sold        20.0
# Name: Tuesday, dtype: object ['Units Sold']
#
#
#
# Wednesday
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold          35.0
# Name: Wednesday, dtype: object ['Units Sold']
#
#
#
# Wednesday
# Day            Wednesday
# Coffee Type        Latte
# Units Sold          25.0
# Name: Wednesday, dtype: object ['Units Sold']
#
#
#
# Thursday
# Day            Thursday
# Coffee Type    Espresso
# Units Sold         40.0
# Name: Thursday, dtype: object ['Units Sold']
#
#
#
# Thursday
# ...

# %%
biox.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios = biox

# %%
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
x=pd.Series([1,2,3,4,5])

# %%
x
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# filtering data set
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
bios.loc[bios["height_cm"]>215]
# Out:
#         athlete_id                   name   born_date               born_city  \
# 5089          5108     Viktor Pankrashkin  1957-06-19         Moskva (Moscow)
# 5583          5606   Paulinho Villas Boas  1963-01-26               São Paulo
# 5673          5696         Gunther Behnke  1963-01-19              Leverkusen
# 5716          5739               Uwe Blab  1962-03-26        München (Munich)
# 5781          5804         Tommy Burleson  1952-02-24               Crossnore
# 5796          5819          Andy Campbell  1956-07-21               Melbourne
# 6223          6250            Lars Hansen  1954-09-27  København (Copenhagen)
# 6270          6298            Hu Zhangbao  1963-04-05                     NaN
# 6409          6440       Sergey Kovalenko  1947-08-11                     NaN
# 6420          6451          Jānis Krūmiņš  1930-01-30                   Cēsis
# 6504          6537            Luc Longley  1969-01-19               Melbourne
# ...

# %%
######### Short Hand Syntax

bios[(bios['height_cm'] >215) & (bios['born_country']=='USA')]
# Out:
#         athlete_id              name   born_date  born_city     born_region  \
# 5781          5804    Tommy Burleson  1952-02-24  Crossnore  North Carolina
# 6722          6755  Shaquille O'Neal  1972-03-06     Newark      New Jersey
# 6937          6972    David Robinson  1965-08-06   Key West         Florida
# 123850      126093    Tyson Chandler  1982-10-02    Hanford      California
#
#        born_country            NOC  height_cm  weight_kg died_date
# 5781            USA  United States      223.0      102.0       NaN
# 6722            USA  United States      216.0      137.0       NaN
# 6937            USA  United States      216.0      107.0       NaN
# 123850          USA  United States      216.0      107.0       NaN

# %%
bios[bios["name"].str.contains("ken")]
# Out:
#         athlete_id                      name   born_date   born_city  \
# 5342          5361             Mukendi Mbuyi  1960-04-26     Kananga
# 5350          5369      Carol Menken-Schaudt  1957-11-23      Albany
# 5383          5402           Lukengu Ngalula  1971-08-11    Kinshasa
# 5415          5434         Kakengwa Pikinini  1971-06-29      Bukavu
# 5642          5665                Ole Bakken  1922-05-24     Harstad
# ...            ...                       ...         ...         ...
# 144661      148357   Leonie Gerken Schofield  1998-02-15  Chelmsford
# 144662      148358  Makayla Gerken Schofield  1999-06-04  Chelmsford
# 144741      148442        Leon Vockensperger  1999-08-25   Rosenheim
# 144980      148689    Fabian Wilkens Solheim  1996-04-10        Oslo
# 144982      148691         Emilie Kalkenberg  1997-07-06         NaN
#
#               born_region born_country                               NOC  \
# ...

# %%
# mcKinney a data scientist and sd created pandas in 2008 
#  Reason for creation is while working at aqr capital management , was faced challenges analyzing large financial datset , existing tools like excel were inefficient for large scale data cleaning and analysis

# %%
# pandas is a powerful and pouplor library for data manupulation and analysisi


# work with csv and excel 
# Handles missing values easily
# built on numpy for fast computations

# why use pandas??

# performance
#easee of use 
#integration

# %%
######### real example 

# dunance 
#retail #
# health care

# %%
########import pandas


# import data as df

#df.head

# dataframe we will import into a variable and access that variable and work on it


# progress is so good

# %%
# pandas head and tail

# %%
# df.head(10)
# df.tail(15)

# column 'rows' , what type of data
