# %% [markdown]
# What is NLP

# %% [markdown]
# Nlp means natural language processing
# it is a part of AI that helps computer understand , read , write and talk like humans.
#
# In short , NLP allow Machines to process human langugage like english , hindi etc instead of zero and ones

# %% [markdown]
# . You type "Weather in Delhi" in Google. Google
# understands your text and shows you the correct
# answer. That's NLP.
#
# . You say, "Hey Alexa, play Arijit Singh songs" Alexa
# listens, understands your sentence, and plays the song that you like to here

# %% [markdown]
# Again just for the sake of your machine to
# understand the language we use NLP. And this
# language is different from the computer languages
# like python , Java , C etc.
# This is real language Hindi, English, french etc.

# %% [markdown]
# Real world Applications
# Chatbots & Virtual Assistants
# " Examples: ChatGPT, Alexa, Siri, Google Assistant
# . NLP allows these tools to understand what
# you're saying or typing.
# . They recognize your intent and give a relevant
# response.
# · This involves speech recognition, text understanding, and response generation

# %% [markdown]
# Sentiment Analysis:
# example twitter analysis, amazon reviews, costumer feedback
#
# - Compnies use for weather people feel positive , negative and neutral
#
# - Now there are more and mroe applications in use and the list goes on and on and the use is growing more and more
#
# from chatbots to threat detection , from text recognition to text generation , speach recognition to speach generation

# %% [markdown]
# ## Approaches of nlp to analyze text data
#
#
# - - You write rules manually
#
# 1. Rule-Based Approach (Old School NLP)
# Example:
# A rule like:
# "If sentence contains 'not good', mark it as negative
# sentiment."
# Used for:
#
# . Grammar checkers
# · Spell check
# . Simple keyword-based chatbots

# %% [markdown]
# Limitation:
# · Can't handle complex, ambiguous, or new
# patterns
# · Not scalable for large data

# %% [markdown]
# 2. Statistical (Machine Learning) Approach
# II Language is treated like data, and algorithms learn
# patterns from it.
# . Use of models like:
# . Naive Bayes
# . Logistic Regression
# Vector Machines)
# Machin

# %% [markdown]
# it does not able to understand the sequence of words so it does loose context

# %% [markdown]
# also it does not undestand the complete sercasm

# %% [markdown]
# to get the context of the sentence we do need some other approach so that we can work on it

# %% [markdown]
# 3 .  Deep learning based approach (Modern NLP)
#
# It uses neural nets to automatically learn complex patterns and context from text
# models can understand meaning , context , word order
# and more
#
#
# - Models can understand meaning, context , word order and more
# - Popular architectures :
#
#     - RNN (Recurrent Neural Network)
#     - LSTM (Long Short Term Memory)
#     - GRU/CNN (Gated Recurrent Units)
#     - Transformers (BERT, GPT, T5 etc)
#     - AUto Encoders

# %% [markdown]
# Even in deep learning, we have to convert text into
# numbers but we don't use traditional techniques lik
# Bag of Words or TF-IDF. Instead, we use more
# advanced methods like Word Embeddings
# (Word2Vec, GloVe) or Token IDs with Embedding
# Layers, which actually capture the meanin- and
# context of words.

# %% [markdown]
# ### Challenges in NLP
#
# - Nlp work on natural language but natural language is challenging to work on
#
# 1. Ambiguity -
#      I saw the boy on the beach with my binoculars. , I have never tasted a cake quite like that one before!
#
# 2. Contextual Words
#     I ran to the store because we ran out of milk
#
# 3. Colloquialisms and slangs
#     Peice of cake, Pulling your leg
#
# 4. Synonyms
#
# 5. Irony, Sarcasm and tonal diff
#      Thats just what i needed today
#
# 6. Spelling Error
#
# 7. Cretivity
#
# 8. Diversity

# %% [markdown]
# Now since we haven't learned Deep Learning yet, in
# this video we'll focus on how NLP works with
# traditional Machine Learning using techniques like
# Bag of Words and TF-IDF. Once we complete Deep
# Learning, we'll dive into advanced embedding
# techniques like Word2Vec and BERT, and L ..:!.
# powerful models using those.

# %%
# Pipeline of NLP

# %% [markdown]
# Now again pipeline are different for Machine
# learning and deep learning but still lets first see
# some of the first steps we do in both.

# %% [markdown]
# 1. Getting the datasets
#     - You can use the prebuild public data for this
#     - You can also do web scrapping when data is not available ready made
#     - API ( Structured and legal way to get live data)
#     - use manual collection or croud sourcing
#     - Use NLP tools to auto generate data (Text - argumentation)
# 2. Text Cleaning
#     - Convert all to lower case
#     - Remove punctuations for ml models not for dl models
#     - Remove digits if require
#     - Remove url or links if necessa//ry
#     - remove html tags
#     - remove emojis
#     - remove stopwords
#     - optional ( correct spellings )
